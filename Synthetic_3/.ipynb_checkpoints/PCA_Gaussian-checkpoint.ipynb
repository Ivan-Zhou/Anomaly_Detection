# %%
import pandas as pd
import numpy as np
import os
os.chdir('../') # Go to the parent folder
from support_functions import *
# Out:
# Using TensorFlow backend.

# %%
# read_funcs = [read_mnist_data,get_yale_faces_data,read_synthetic_data,read_synthetic_data,read_synthetic_data,read_synthetic_data]
# parameters = ['','','Synthetic/','Synthetic_2/','Synthetic_3/','Synthetic_4/']
# detect_funcs = [detection_with_pca_reconstruction_error,detection_with_pca_gaussian,detection_with_autoencoder_reconstruction_error,detection_with_autoencoder_gaussian]

# Execution
read_func = read_synthetic_data
parameter = 'Synthetic_3/'
detect_func = detection_with_pca_gaussian
read_and_detect(read_func,detect_func,parameter,to_print = True)
# Out:
# Start the Anomaly Detection with PCA and Multivariate Gaussian Method:
# Summary of PCA Encoding:
# Number of Dimension in the Original Dataset: 16
# Number of Dimension in the PCA-Encoded Dataset: 16
# 97.0% variance is retained with the current PCA Reconstruction.
# Training Results:
# Precision: 15.0%
# Recall: 80.5%
# F-score: 24.1%
# R-Precision (# R = 7020.0): 53.8%
# Precision@20: 100.0%
#
# Testing Results:
# Precision: 15.0%
# Recall: 81.4%
# F-score: 24.4%
# R-Precision (# R = 2980.0): 55.1%
# Precision@20: 100.0%
