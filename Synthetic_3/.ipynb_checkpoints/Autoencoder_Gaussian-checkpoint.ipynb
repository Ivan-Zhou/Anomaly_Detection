# %%
import pandas as pd
import numpy as np
import os
os.chdir('../') # Go to the parent folder
from support_functions import *
# Out:
# Using TensorFlow backend.

# %%
# read_funcs = [read_mnist_data,get_yale_faces_data,read_synthetic_data,read_synthetic_data,read_synthetic_data,read_synthetic_data]
# parameters = ['','','Synthetic/','Synthetic_2/','Synthetic_3/','Synthetic_4/']
# detect_funcs = [detection_with_pca_reconstruction_error,detection_with_pca_gaussian,detection_with_autoencoder_reconstruction_error,detection_with_autoencoder_gaussian]

# Execution
read_func = read_synthetic_data
parameter = 'Synthetic_3/'
detect_func = detection_with_autoencoder_gaussian
read_and_detect(read_func,detect_func,parameter,to_print = True)
# Out:
# Start the Anomaly Detection with Deep Autoencoder and Multivariate Gaussian Model:
# Below is a summery of the encoder model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 13)                221
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                140
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 88
# =================================================================
# Total params: 449
# Trainable params: 449
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#  The output shape of the encoder model:
# (None, 8)
# Below are examples of the Reconstructed Data with Deep Autoencoder
# Finish evaluate Lambda: 0
# Finish evaluate Lambda: 0.09
# Finish evaluate Lambda: 0.18
# Finish evaluate Lambda: 0.27
# Finish evaluate Lambda: 0.36
# Finish evaluate Lambda: 0.44999999999999996
# Finish evaluate Lambda: 0.5399999999999999
# Finish evaluate Lambda: 0.6299999999999999
# Finish evaluate Lambda: 0.7199999999999999
# Finish evaluate Lambda: 0.8099999999999998
# Finish evaluate Lambda: 0.8999999999999998
# Finish evaluate Lambda: 0.9899999999999998
# The best lambda selected from the cross validation is: 0.09
# Training Results:
# Precision: 9.8%
# Recall: 98.8%
# F-score: 17.9%
# R-Precision (# R = 6922.0): 9.2%
# Precision@20: 65.0%
#
# Testing Results:
# Precision: 10.2%
# Recall: 98.5%
# F-score: 18.4%
# R-Precision (# R = 3078.0): 9.3%
# Precision@20: 40.0%
