# %%
from processing_functions_yale_faces import * #

import os
os.chdir('../') # Go to the parent folder
from support_functions import *
from Autoencoder_Functions import *
from PCA_Functions import *
os.chdir('Yale_Faces_Data')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Define Parameters

# %%
k = 10 # k to be used for the precision k metric
model_path = 'model_autoencoder.h5'
data_path = 'CroppedYale/'

# %% [markdown]
# ## Read Data

# %%
# Read image matrix (n*m), labels (vector of m), and image size
imgs, labels, height, width = get_yale_faces_data(data_path)

# Split the images and labels
imgs_train,imgs_test,labels_train,labels_test = split_data_labels_training_testing(imgs,labels)

# %% [markdown]
# ## Implement the Anomaly Detection
# ### Reconstruction Error

# %%
detection_with_autoencoder_reconstruction_error(imgs_train, imgs_test,labels_train,labels_test,k,model_path,is_image_data=True,to_print = True,height=height,width=width)
# Out:
# Below is a summery of the autoencoder model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 504)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 252)               127260
# _________________________________________________________________
# dense_2 (Dense)              (None, 126)               31878
# _________________________________________________________________
# dense_3 (Dense)              (None, 63)                8001
# _________________________________________________________________
# dense_4 (Dense)              (None, 31)                1984
# _________________________________________________________________
# dense_5 (Dense)              (None, 62)                1984
# _________________________________________________________________
# ...

# %% [markdown]
# ### Multivariate Gaussian Method

# %%
detection_with_autoencoder_gaussian(imgs_train, imgs_test,labels_train,labels_test,k,model_path,is_image_data=True,to_print = True,height=height,width=width)
# Out:
# Below is a summery of the encoder model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 504)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 252)               127260
# _________________________________________________________________
# dense_10 (Dense)             (None, 126)               31878
# _________________________________________________________________
# dense_11 (Dense)             (None, 63)                8001
# _________________________________________________________________
# dense_12 (Dense)             (None, 31)                1984
# ...
# Total params: 169,123
# Trainable params: 169,123
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#  The output shape of the encoder model:
# (None, 31)
# ...
