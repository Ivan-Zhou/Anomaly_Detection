# %%
import numpy as np  
from keras.layers import Input, Dense
from keras.models import Model
from keras.models import load_model
from processing_functions import * 

import os
os.chdir('../') # Go to the parent folder
from support_functions import *
from Autoencoder_Functions import *
os.chdir('MNIST')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Parameters

# %%
anomaly_digit = 2 # Set digit 2 as our anomaly
n_components=30 # 30 components in the encoded matrix
k = 50 # Define the k parameter for the precision at k

# %% [markdown]
# ## Read Data

# %%
data_path = 'data/input_data/'
# Read image matrix (n*m), labels (vector of m), and image size
imgs_train, imgs_test, labels_train, labels_test, height, width = read_process_data(data_path, anomaly_digit)
# The length of one image vector
img_size = height*width

# %% [markdown]
# ### Load the Saved Models
# #### Autoencoder Model

# %%
# Generate and Compile a Deep Autoencoder
# Specify the model config
encoder_layers_size, decoder_layers_size = get_deep_model_config()
# Extract the saved model
autoencoder, encoder = compile_autoencoder(img_size,encoder_layers_size, decoder_layers_size) 
autoencoder = load_model('model_autoencoder.h5') # Load the saved model

# %% [markdown]
# #### Encoder Model
# Encoder is the first half of the autoencoder model and it is not compiled; thus, we retrieve the encoder model based on the autoencoder one.

# %%
weights_encoder = autoencoder.get_weights()[0:4] # The first half of the autoencoder model is an encoder model
encoder.set_weights(weights_encoder) # Set weights

# %%
print(encoder.summary())
print("\n The output shape of the encoder model: ")
print(encoder.output_shape)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# =================================================================
# Total params: 141,536
# Trainable params: 141,536
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#  The output shape of the encoder model:
# (None, 32)

# %% [markdown]
# ### Visualize the Reconstructed Image

# %%
imgs_train_reconstructed = reconstruct_with_autoencoder(autoencoder,imgs_train,visual =True,height = height, width = width)

# %% [markdown]
# ## Implement the Anomaly Detection with the Gaussian Distribution

# %% [markdown]
# ### Encode the images in the Training Set and the Testing Set

# %%
imgs_train_encoded = encode_data(encoder, imgs_train)
imgs_test_encoded = encode_data(encoder, imgs_test)

# %% [markdown]
# ### Visualize the Distribution of Data Points in the encoded matrix

# %%
plot_matrix_data(imgs_train_encoded)

# %% [markdown]
# ### Detector

# %%
train_test_with_gaussian(imgs_train_encoded, imgs_test_encoded, labels_train, labels_test)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-10-3a4f83d2f781> in <module>()
# ----> 1 train_test_with_gaussian(imgs_train_encoded, imgs_test_encoded, labels_train, labels_test)
#
# /home/ivan/ML/Anomaly_Detection/support_functions.py in train_test_with_gaussian(data_train, data_test, labels_train, labels_test)
#     428     # Get Gaussian Distribution Model with the Training Data
#     429     # Note: fit_multivariate_gaussian() is my own coded function
# --> 430     dist = fit_multivariate_gaussian(data_train)
#     431
#     432     # Get Probability of being Anomaly vs. being Normal
#
# /home/ivan/ML/Anomaly_Detection/support_functions.py in fit_multivariate_gaussian(data)
#     153     """
#     154     mu, cov = estimate_gaussian(data)
# --> 155     dist = multivariate_normal(mean = mu, cov = cov,allow_singular=False)
#     156     return dist
#     157
#
# /home/ivan/anaconda3/lib/python3.6/site-packages/scipy/stats/_multivariate.py in __call__(self, mean, cov, allow_singular, seed)
#     349         return multivariate_normal_frozen(mean, cov,
#     350                                           allow_singular=allow_singular,
# --> 351                                           seed=seed)
#     352
#     353     def _process_parameters(self, dim, mean, cov):
#
# /home/ivan/anaconda3/lib/python3.6/site-packages/scipy/stats/_multivariate.py in __init__(self, mean, cov, allow_singular, seed)
#     599         self.dim, self.mean, self.cov = self._dist._process_parameters(
#     600                                                             None, mean, cov)
# --> 601         self.cov_info = _PSD(self.cov, allow_singular=allow_singular)
#     602
#     603     def logpdf(self, x):
#
# /home/ivan/anaconda3/lib/python3.6/site-packages/scipy/stats/_multivariate.py in __init__(self, M, cond, rcond, lower, check_finite, allow_singular)
#     155         d = s[s > eps]
#     156         if len(d) < len(s) and not allow_singular:
# --> 157             raise np.linalg.LinAlgError('singular matrix')
#     158         s_pinv = _pinv_1d(s, eps)
#     159         U = np.multiply(u, np.sqrt(s_pinv))
#
# LinAlgError: singular matrix
