# %%
import numpy as np

import os
os.chdir('../') # Go to the parent folder
from support_functions import *
# Out:
# Using TensorFlow backend.

# %%
AnomalyData, data_train, data_test, labels_train, labels_test=read_mnist_data()

# %%
encode_and_viz_corr(AnomalyData, data_train,labels_train)
# Out:
# Below is the 2D Visualization of the correlation in the encoded data with PCA:
# Below: Heatmap of the Correlation Matrix
# Below is the 2D Visualization of the correlation in the encoded data with Deep Autoencoder:
# Below is a summery of the encoder model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# ...
