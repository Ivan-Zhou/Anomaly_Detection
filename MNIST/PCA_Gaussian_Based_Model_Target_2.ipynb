# %%
import numpy as np
from processing_functions import * 

import os
os.chdir('../') # Go to the parent folder
from support_functions import *
from PCA_Functions import *
os.chdir('MNIST')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Define Parameters

# %%
anomaly_digit = 2 # Set digit 2 as our anomaly

# %% [markdown]
# ## Read Datasets

# %% [markdown]
# ### Load all saved datasets

# %%
data_path = 'data/input_data/'
# Read image matrix (n*m), labels (vector of m), and image size
imgs_train, imgs_test, labels_train, labels_test, height, width = read_process_data(data_path, anomaly_digit)
# The length of one image vector
img_size = height*width

# %% [markdown]
# ## PCA Method
# ### Apply PCA to Encode the images

# %%
# Define the number of Principal Components to keep from the image
n_components  = 200

# %%
# Compute PCA with training dataset
imgs_train_encoded,pca_matrix, component_mean = pca_all_processes(imgs_train,labels_train,n_components, plot_eigenfaces_bool = True,decode = False, height=height,width=width)

# Encode the test set
imgs_test_encoded = encode_pca(imgs_test, component_mean,pca_matrix,n_components)
# Out:
# Below is the eigenfaces from the PCA Matrix

# %% [markdown]
# ### Anomaly Detection with Multivariate Gaussian on PCA

# %%
train_test_with_gaussian(imgs_train, imgs_test, labels_train, labels_test)
# Out:
# /home/ivan/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3193: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.0, top=0.0
#   'bottom=%s, top=%s') % (bottom, top))
# Training Results:
# Precision: 0.0%
# Recall: 0.0%
# F-score: 0.0%
# Precision@5958.0: 0.0%
# /home/ivan/ML/Anomaly_Detection/support_functions.py:260: RuntimeWarning: invalid value encountered in double_scalars
#   for epsilon in np.arange(p_ranked.min(), p_ranked.max(), step):
# Precision: 0.0%
# Recall: 0.0%
# F-score: 0.0%
# Precision@1032.0: 0.0%
