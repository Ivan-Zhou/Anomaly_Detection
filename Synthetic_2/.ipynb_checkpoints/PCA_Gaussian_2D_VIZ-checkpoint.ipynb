# %%
import numpy as np
from processing_functions import * 

import os
os.chdir('../') # Go to the parent folder
from support_functions import *
from PCA_Functions import *
os.chdir('Synthetic_2')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Define Parameters

# %%
k = 50 # Used to compute the precision @ k

# %% [markdown]
# ## Read Datasets

# %%
data, labels, data_train, data_test, labels_train, labels_test = read_data()

# %%
plot_data_2d(data, labels)
# Out:
# 54.4% variance is retained with the current PCA Encoding.
