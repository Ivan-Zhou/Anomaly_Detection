# %%
import os
os.chdir('../../') # Go to the parent folder
from AnomalyDataClass import * # Functions to extract parameters of each data files 
from support_functions import *
# Out:
# Using TensorFlow backend.

# %%
# Set up the read functions and parameter
read_funcs = [read_mnist_data,get_yale_faces_data,read_synthetic_data,read_synthetic_data,read_synthetic_data,read_synthetic_data]
parameters = ['','','Synthetic/','Synthetic_2/','Synthetic_3/','Synthetic_4/']

# %%
i = 1 # Read Yale Faces Data
read_encode_viz_corr(read_funcs[i],parameters[i])
# Out:
# The data has been extracted from the folder: Yale_Faces_Data/
# Below is the 2D Visualization of the correlation in the encoded data with PCA:
# Below: Heatmap of the Correlation Matrix
# Below is the 2D Visualization of the correlation in the encoded data with Deep Autoencoder:
# Below is a summery of the encoder model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 504)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 252)               127260
# _________________________________________________________________
# dense_2 (Dense)              (None, 126)               31878
# _________________________________________________________________
# dense_3 (Dense)              (None, 63)                8001
# _________________________________________________________________
# dense_4 (Dense)              (None, 31)                1984
# =================================================================
# Total params: 169,123
# Trainable params: 169,123
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#  The output shape of the encoder model:
# (None, 31)
# There is NaN in the correlation matrix!
# /home/ivan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3003: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/ivan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3004: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# Below: Heatmap of the Correlation Matrix
